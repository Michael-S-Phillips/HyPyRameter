# %% [markdown]
# # Example run of HyPyRameter Image Cube Calculator

# %%
#Import the module
from hypyrameter.ImageCubeParameters.paramCalculator import paramCalculator

# %%
# Instantiate the class and select your input image and output directory
pc = paramCalculator()
# Out:
# Select input hyperspectral cube
# 2023-10-05 08:59:12.359 python[60876:5054775] +[CATransaction synchronize] called within transaction
# Selected file: /Volumes/Utumno/EMIT/EMIT-Data-Resources/data/EMIT_L2A_RFL_001_20230329T145406_2308809_052_reflectance_cropped.hdr
# loading /Volumes/Utumno/EMIT/EMIT-Data-Resources/data/EMIT_L2A_RFL_001_20230329T145406_2308809_052_reflectance_cropped.hdr using spectral
# 	objects loaded
#
# Select output directory
# 2023-10-05 08:59:20.184 python[60876:5054775] +[CATransaction synchronize] called within transaction
# Selected output directory: /Users/phillipsm/Documents/Software/HyPyRameter/example_output/updated
# loading data
# 	data loaded
# valid parameters:
# 	['R463', 'R550', 'R637', 'R1080', 'R1506', 'R2529', 'HCPINDEX2', 'LCPINDEX2', 'OLINDEX3', 'SINDEX2', 'GINDEX', 'BD530_2', 'BD670', 'BD875', 'BD905', 'BD920_2', 'BD1200', 'BD1400', 'BD1450', 'BD1750', 'BD1900_2', 'BD1900r2', 'BD2100_2', 'BD2100_3', 'BD2165', 'BD2190', 'BD2210_2', 'BD2250', 'BD2265', 'BD2290', 'BD2355', 'BDCARB', 'BA1200', 'BA1450', 'BA1900', 'D460', 'D700', 'D2200', 'D2300', 'MIN2295_2480', 'MIN2250', 'MIN2345_2537', 'RPEAK1', 'BDI1000VIS', 'ISLOPE', 'IRR2']
# 0.22 minutes to load data

# %%
# Run the calculator and save the results
pc.run()
# Out:
# calculating valid parameters
# ['R463', 'R550', 'R637', 'R1080', 'R1506', 'LCPINDEX2', 'OLINDEX3', 'SINDEX2', 'GINDEX', 'BD530_2', 'BD670', 'BD875', 'BD905', 'BD920_2', 'BD1200', 'BD1400', 'BD1450', 'BD1750', 'BD1900_2', 'BD1900r2', 'BD2100_2', 'BD2100_3', 'BD2165', 'BD2190', 'BD2210_2', 'BD2250', 'BD2265', 'BD2290', 'BD2355', 'BA1200', 'BA1450', 'BA1900', 'D460', 'D700', 'D2200', 'MIN2250', 'RPEAK1', 'BDI1000VIS']
# 	preparing polynomial arguments
# 100%|██████████| 47700/47700 [00:00<00:00, 1040261.54it/s]
# 	calculating polynomials
# 	returning peak reflectance and wavelengths of peak reflectance
# 47700it [00:02, 23720.84it/s]
# 	re-shaping arrays
# 	normalizing input data
# 100%|██████████| 22/22 [00:00<00:00, 5712.90it/s]
# 	preparing polynomial arguments
# 100%|██████████| 47700/47700 [00:00<00:00, 195087.14it/s]
# 	returning integrated polynomial values
# 	reshaping array
# calculation took 0.4 minutes
# Header file /Users/phillipsm/Documents/Software/HyPyRameter/example_output/updated/EMIT_L2A_RFL_001_20230329T145406_2308809_052_reflectance_cropped_params.hdr already exists. Use `force` keyword to force overwrite.
# calculating valid browse products
#
# valid browse products:
# ['BIO', 'FM2', 'FM3', 'HEM', 'HYD', 'HYD2', 'HYD3', 'HYS', 'PAL', 'SUL', 'TRU']
# /Users/phillipsm/Documents/Software/HyPyRameter/hypyrameter/ImageCubeParameters/param_utils.py:322: RuntimeWarning: divide by zero encountered in divide
#   sp = (img_array - lower_percentile) * 255 / (upper_percentile - lower_percentile)
# /Users/phillipsm/Documents/Software/HyPyRameter/hypyrameter/ImageCubeParameters/param_utils.py:322: RuntimeWarning: invalid value encountered in divide
#   sp = (img_array - lower_percentile) * 255 / (upper_percentile - lower_percentile)
# /Users/phillipsm/Documents/Software/HyPyRameter/hypyrameter/ImageCubeParameters/param_utils.py:298: RuntimeWarning: invalid value encountered in divide
#   A[:,:,i] = np.array((255*((b-np.nanmin(b))/(np.nanmax(b)-np.nanmin(b)))),dtype='int')
# /Users/phillipsm/Documents/Software/HyPyRameter/hypyrameter/ImageCubeParameters/param_utils.py:298: RuntimeWarning: invalid value encountered in cast
#   A[:,:,i] = np.array((255*((b-np.nanmin(b))/(np.nanmax(b)-np.nanmin(b)))),dtype='int')
# /Users/phillipsm/Documents/Software/HyPyRameter/hypyrameter/ImageCubeParameters/param_utils.py:322: RuntimeWarning: divide by zero encountered in divide
#   sp = (img_array - lower_percentile) * 255 / (upper_percentile - lower_percentile)
# /Users/phillipsm/Documents/Software/HyPyRameter/hypyrameter/ImageCubeParameters/param_utils.py:322: RuntimeWarning: invalid value encountered in divide
#   sp = (img_array - lower_percentile) * 255 / (upper_percentile - lower_percentile)
# /Users/phillipsm/Documents/Software/HyPyRameter/hypyrameter/ImageCubeParameters/param_utils.py:298: RuntimeWarning: invalid value encountered in divide
#   A[:,:,i] = np.array((255*((b-np.nanmin(b))/(np.nanmax(b)-np.nanmin(b)))),dtype='int')
# /Users/phillipsm/Documents/Software/HyPyRameter/hypyrameter/ImageCubeParameters/param_utils.py:298: RuntimeWarning: invalid value encountered in cast
#   A[:,:,i] = np.array((255*((b-np.nanmin(b))/(np.nanmax(b)-np.nanmin(b)))),dtype='int')
